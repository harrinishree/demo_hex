# %%
print("Hi")

# %%
import keyword

print(keyword.kwlist)

# %%
name="Harrini"
age=21
ID=116
print(name,age,id)
print(type(name))
print(type(ID))
print(type(age))
print(id(name))
# Out:
# Harrini 21 <built-in function id>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# 2227667080304

# %%
a=2
b=3
c=5
d=7
print(a+b)
print(a-b)
print(c*d)
print(c/d)
print(c//d)
print(a**c)
print(b%c)
# Out:
# 5
# -1
# 35
# 0.7142857142857143
# 0
# 32
# 3

# %%
'''a=10
b=20.5
c='abc'
d=10
print(a,type(a),id(a))
print(b,type(b),id(b))
print(c,type(c),id(c))
print(d,type(d),id(d))

Stu_name='Rajni Kant' # text or string or categorical
Sub_name="Python Program"  # text or string or categorical
Stu_Address=AB5
 ST 8
 Raja Ji Nagar
 Bangalore-10
print(Stu_name,Sub_name,Stu_Address)

# data types=> int,float,str,bool
a=10
b=20.5
c='abc'
d=False
print(type(a),type(b),type(c),type(d))
# arithmetic operators
a=10
b=3
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)

a=2
b=3
c=3
print(a*b*c) #512
print(2**27)

#relational or comparison operator
a=10
b=5
print(a>b)
print(a<b)
print(a==b)
print(a!=b)
print(a>=b)
print(a<=b)



a='python'
b='programming'
print(a+b)#concatenation
print(a*2)#repetition

from itertools import count

#list(data structure,multiple value,ordered,mutable,iterable,duplicate,index,sliced)
l=[1,2,3,4,5,6,7,8,9]
print(l)
print(len(l))
print(l[0])
print(l[-1])
print(l[-2])
print(l[::-1])#reversed order
l[0]=2#mutable
print(l)
for item in l:
    print(item+2,end=" ")
print()
print(l)
print(dir(l))
l.append(100)
l.insert(1,200)
print(l)
print(l.count(9))
print(l.index(2))
l.remove(2)
print(l)
l.pop(0)#remove item from list in given index
print(l)
l.reverse()
print(l)
l.sort(reverse=True)
print(l)
#l.clear()
l2=l#assignment
l3=l.copy()#copy
l.append(-1)
print(l)
print(l2)
print(l3)


l=[1,2,3,4,5,6]
#print(l)
#l.sort(reverse=True)
#print(l[:3])
# slicing
print(l)
print(l[0:5:2])
print(l[2::1])#st=>start,st=>stop,st=>step
def sum(a,b):
    return a+b,b+10

result=sum(10,20)
print(type(result))

## tuple=>(data structure,ordered,disimilar,duplicate,slicing,iterable,index,imutable)
t=(1,2,3,4,5,6,10.5,1)
print(type(t))
print(dir(t))
print(t)
print(t.count(3))
print(t.index(3))
print(t[::2])
l=max(t)# sum(),max(),min(),reversed(),sorted()
print(l)


# set=>data structure,unordered,unindex,unique,mutable,iterable,disimilar data
s={1,1,2,2,40,10,70,'Amit'}
s.add(100)
print(s)
for item in s:
    print(item,end=" ")
print(dir(s))
s1={1,2,3,4,5}
s2={1,2,3,4,5,6,7}
print(s1.issubset(s2))
print(s2.issuperset(s1))
print(s1.union(s2))
print(s1.intersection(s2))
print(s2.difference(s1))
print(s1.symmetric_difference(s2))
'''
# dictionary=>ordered,data structure,mutable,iterable,duplicate on values,disimilar,key:value,index with keys
d={10:"BTech",2:4,3:6,4:6,4:100}
print(d)
print(type(d))
print(d.keys())
print(d.values())
print(d.items())
print(d[3],d.get(3))
for key,value in d.items():
    if key%2==0:
        print(key,value)
print(dir(d))

# 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values'

d.update({100:200})
print(d)
d.pop(100)#100 key value deleted from dict
print(d)
d.popitem()#delete last pair from the dict
print(d)
